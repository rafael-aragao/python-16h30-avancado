# %%
import pyautogui
import time

pyautogui.alert("Para começar, aperte OK e não mexa em nada")

pyautogui.press("win")

time.sleep(3)

pyautogui.write("chrome")

time.sleep(3)

pyautogui.click(142, 240)
